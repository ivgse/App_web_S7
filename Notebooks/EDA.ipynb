# %%
import pandas as pd
import plotly.express as px

# %%
autos = pd.read_csv('/Users/IvanSoto/Desktop/Python/Sprint7_Git/App/App_web_S7/vehicles_us.csv')
print(autos.sample(10))
autos.info()
# Out:
#        price  model_year                model  condition  cylinders    fuel  \
# 20721   8499      2011.0             acura tl  excellent        6.0     gas
# 48518   4750      2012.0          ford escape       good        NaN     gas
# 47964   7500      2011.0         toyota prius       good        4.0  hybrid
# 33931  19500      2013.0            ford f150  excellent        6.0     gas
# 46704  10500      2008.0           gmc sierra  excellent        8.0     gas
# 51134   3500      2004.0      toyota camry le  excellent        4.0     gas
# 25319  42990      2015.0        ford f-250 sd       good        8.0  diesel
# 45881   4500      2012.0         chrysler 200       good        4.0     gas
# 3764   15200      2006.0        jeep wrangler  excellent        NaN     gas
# 40232   7000      2013.0  dodge grand caravan       good        NaN     gas
#
#        odometer transmission       type paint_color  is_4wd date_posted  \
# ...

# %%
plt= px.scatter(autos, x='odometer', y='price', color='type', title='Scatter plot of price vs odometer')
plt.show()
id_max= autos['price'].idxmax()
print(autos.loc[id_max])
# Out:
# price                    375000
# model_year               1999.0
# model           nissan frontier
# condition                  good
# cylinders                   6.0
# fuel                        gas
# odometer               115000.0
# transmission          automatic
# type                     pickup
# paint_color                blue
# is_4wd                      1.0
# date_posted          2018-05-19
# days_listed                  21
# Name: 12504, dtype: object

# %%
autos.columns
# Out:
# Index(['price', 'model_year', 'model', 'condition', 'cylinders', 'fuel',
#        'odometer', 'transmission', 'type', 'paint_color', 'is_4wd',
#        'date_posted', 'days_listed'],
#       dtype='object')
